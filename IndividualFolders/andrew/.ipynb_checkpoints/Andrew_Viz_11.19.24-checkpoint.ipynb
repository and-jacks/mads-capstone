# %%
import sys
import numpy as np
import pandas as pd
import statsmodels.api as sm
import os
import warnings
import folium
import branca

warnings.filterwarnings("ignore")

# %%
df_filled_23 = pd.read_pickle(r'D:\capstone_F24\data\Cleaned_data\df_filled_23.pkl')

# %%
df_filled_23
# Out:
# timestamp           2023-02-01 00:00:00  2023-02-01 01:00:00  \
# station_complex_id
# 1                                  27.0                 16.0
# 10                                167.0                 46.0
# 100                                13.0                  2.0
# 101                                59.0                 30.0
# 118                                94.0                 25.0
# ...                                 ...                  ...
# 95                                 15.0                  3.0
# 96                                 13.0                  6.0
# 97                                 31.0                 14.0
# 98                                 31.0                  5.0
# 99                                 14.0                  1.0
#
# timestamp           2023-02-01 02:00:00  2023-02-01 03:00:00  \
# station_complex_id
# 1                                  15.0                 16.0
# 10                                 26.0                 10.0
# 100                                 1.0                  2.0
# 101                                13.0                  6.0
# 118                                15.0                  3.0
# ...                                 ...                  ...
# 95                                  6.0                 13.0
# 96                                  5.0                  8.0
# 97                                 19.0                 22.0
# 98                                 10.0                  4.0
# 99                                  4.0                  1.0
#
# timestamp           2023-02-01 04:00:00  2023-02-01 05:00:00  \
# station_complex_id
# 1                                  47.0                227.0
# 10                                  8.0                 25.0
# 100                                 6.0                 15.0
# 101                                18.0                 61.0
# 118                                 4.0                  9.0
# ...                                 ...                  ...
# 95                                 39.0                 87.0
# 96                                 24.0                 72.0
# 97                                 37.0                118.0
# 98                                 26.0                 59.0
# 99                                  8.0                 44.0
#
# timestamp           2023-02-01 06:00:00  2023-02-01 07:00:00  \
# station_complex_id
# 1                                 654.0               1528.0
# 10                                 84.0                222.0
# 100                                75.0                141.0
# 101                               230.0                635.0
# 118                                49.0                 95.0
# ...                                 ...                  ...
# 95                                233.0                566.0
# 96                                193.0                421.0
# 97                                290.0                871.0
# 98                                160.0                310.0
# 99                                116.0                256.0
#
# timestamp           2023-02-01 08:00:00  2023-02-01 09:00:00  ...  \
# station_complex_id                                            ...
# 1                                2208.0               1020.0  ...
# 10                                490.0                399.0  ...
# 100                               281.0                161.0  ...
# 101                              1223.0                765.0  ...
# 118                               188.0                114.0  ...
# ...                                 ...                  ...  ...
# 95                                768.0                433.0  ...
# 96                                621.0                364.0  ...
# 97                               1367.0                837.0  ...
# 98                                429.0                293.0  ...
# 99                                384.0                225.0  ...
#
# timestamp           2023-12-31 14:00:00  2023-12-31 15:00:00  \
# station_complex_id
# 1                                 383.0                334.0
# 10                                  1.0                  4.0
# 100                                81.0                 66.0
# 101                               353.0                364.0
# 118                               212.0                231.0
# ...                                 ...                  ...
# 95                                193.0                197.0
# 96                                175.0                157.0
# 97                                337.0                303.0
# 98                                173.0                186.0
# 99                                104.0                115.0
#
# timestamp           2023-12-31 16:00:00  2023-12-31 17:00:00  \
# station_complex_id
# 1                                 334.0                357.0
# 10                                  3.0                  1.0
# 100                                60.0                 50.0
# 101                               376.0                364.0
# 118                               249.0                236.0
# ...                                 ...                  ...
# 95                                147.0                143.0
# 96                                121.0                136.0
# 97                                282.0                301.0
# 98                                213.0                182.0
# 99                                106.0                 99.0
#
# timestamp           2023-12-31 18:00:00  2023-12-31 19:00:00  \
# station_complex_id
# 1                                 406.0                307.0
# 10                                  4.0                  2.0
# 100                                71.0                 74.0
# 101                               290.0                318.0
# 118                               292.0                286.0
# ...                                 ...                  ...
# 95                                182.0                191.0
# 96                                153.0                214.0
# 97                                289.0                341.0
# 98                                184.0                152.0
# 99                                 88.0                 92.0
#
# timestamp           2023-12-31 20:00:00  2023-12-31 21:00:00  \
# station_complex_id
# 1                                 335.0                319.0
# 10                                  5.0                  3.0
# 100                               101.0                 84.0
# 101                               302.0                270.0
# 118                               309.0                320.0
# ...                                 ...                  ...
# 95                                164.0                141.0
# 96                                159.0                139.0
# 97                                265.0                338.0
# 98                                149.0                119.0
# 99                                 79.0                 92.0
#
# timestamp           2023-12-31 22:00:00  2023-12-31 23:00:00
# station_complex_id
# 1                                 234.0                 63.0
# 10                                  5.0                  2.0
# 100                                54.0                 26.0
# 101                               217.0                107.0
# 118                               326.0                148.0
# ...                                 ...                  ...
# 95                                114.0                 55.0
# 96                                105.0                 51.0
# 97                                207.0                122.0
# 98                                102.0                 39.0
# 99                                 51.0                 27.0
#
# [361 rows x 8016 columns]

# %%
time_cols = df_filled_23.columns

# %%
df_23_pred = pd.read_pickle('df_23_pred.pkl')

# %%
df_23_pred
# Out:
#     station_complex_id                           predicted_ridership_2023  \
# 0                    1  [44.99774297489933, 20.8311131963189, 14.01589...
# 1                   10  [0.6377865430228253, -0.43231439031105057, -0....
# 2                  100  [19.375849590191244, 9.485234104879147, 6.0255...
# 3                  101  [65.80243855395817, 33.77050425148411, 19.5834...
# 4                  118  [69.09470590092661, 31.96459776749566, 17.1971...
# ..                 ...                                                ...
# 356                 95  [33.65158783570899, 17.02208648432609, 15.6516...
# 357                 96  [40.19121795211857, 23.248138439804983, 15.658...
# 358                 97  [50.402836806840995, 27.46710833259318, 30.456...
# 359                 98  [22.130989560671487, 9.10391059220381, 6.10345...
# 360                 99  [13.454066961828353, 6.565974289944839, 3.2425...
#
#                                   predicted_timestamps
# 0    [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 1    [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 2    [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 3    [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 4    [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# ..                                                 ...
# 356  [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 357  [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 358  [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 359  [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
# 360  [2023-01-01 00:00:00, 2023-01-01 01:00:00, 202...
#
# [361 rows x 3 columns]

# %%
df_23_pred = df_23_pred.drop(columns='predicted_timestamps')

# %%
df_23_pred.columns
# Out:
# Index(['station_complex_id', 'predicted_ridership_2023'], dtype='object')

# %%
list_size = df_23_pred[df_23_pred['station_complex_id']=='1']['predicted_ridership_2023'].values.tolist()

# %%
len(list_size[0])
# Out:
# 8016

# %%
# Set index to station_complex_id
df_23_pred = df_23_pred.set_index("station_complex_id")

# Expand the lists in predicted_ridership_2023 into new columns
expanded_23_pred = pd.DataFrame(df_23_pred["predicted_ridership_2023"].tolist(), 
                           index=df_23_pred.index, 
                           columns=time_cols)

expanded_23_pred
# Out:
# timestamp           2023-02-01 00:00:00  2023-02-01 01:00:00  \
# station_complex_id
# 1                             44.997743            20.831113
# 10                             0.637787            -0.432314
# 100                           19.375850             9.485234
# 101                           65.802439            33.770504
# 118                           69.094706            31.964598
# ...                                 ...                  ...
# 95                            33.651588            17.022086
# 96                            40.191218            23.248138
# 97                            50.402837            27.467108
# 98                            22.130990             9.103911
# 99                            13.454067             6.565974
#
# timestamp           2023-02-01 02:00:00  2023-02-01 03:00:00  \
# station_complex_id
# 1                             14.015898            17.815409
# 10                            -0.727984            -0.837661
# 100                            6.025507             4.412437
# 101                           19.583496            13.533800
# 118                           17.197161             9.281847
# ...                                 ...                  ...
# 95                            15.651613            17.484488
# 96                            15.658215            18.239913
# 97                            30.456254            21.037095
# 98                             6.103457             6.337204
# 99                             3.242544             3.171757
#
# timestamp           2023-02-01 04:00:00  2023-02-01 05:00:00  \
# station_complex_id
# 1                             57.416064           185.871864
# 10                            -0.827902            -0.736454
# 100                            9.351398            15.671728
# 101                           19.851599            52.289790
# 118                            8.067009             9.062392
# ...                                 ...                  ...
# 95                            52.051402           125.872212
# 96                            45.443364            99.878363
# 97                            39.479223            79.378789
# 98                            15.613535            28.677702
# 99                             4.518395            16.844445
#
# timestamp           2023-02-01 06:00:00  2023-02-01 07:00:00  \
# station_complex_id
# 1                            434.907199           839.610537
# 10                            -0.336859             0.408229
# 100                           38.628597            70.577131
# 101                          124.091671           261.166142
# 118                           23.617992            63.080299
# ...                                 ...                  ...
# 95                           260.295779           490.976410
# 96                           215.025678           388.856878
# 97                           174.828960           334.269557
# 98                            70.903629           120.816272
# 99                            49.827878            86.619874
#
# timestamp           2023-02-01 08:00:00  2023-02-01 09:00:00  ...  \
# station_complex_id                                            ...
# 1                           1091.586632           749.823880  ...
# 10                             1.845614             2.650850  ...
# 100                          112.912515            94.734594  ...
# 101                          435.244765           327.458649  ...
# 118                           85.784517            87.539774  ...
# ...                                 ...                  ...  ...
# 95                           649.441211           557.557151  ...
# 96                           556.847149           506.690011  ...
# 97                           485.523609           441.372172  ...
# 98                           169.618078           147.678173  ...
# 99                           128.121672           112.202872  ...
#
# timestamp           2023-12-31 14:00:00  2023-12-31 15:00:00  \
# station_complex_id
# 1                           1905.625302          1826.121774
# 10                            -0.668272            -0.588526
# 100                         1440.656373          1566.617181
# 101                          799.036060           931.341885
# 118                          482.319020           675.303655
# ...                                 ...                  ...
# 95                         13014.522558         13202.292374
# 96                        106783.144820        106207.815447
# 97                           556.389733           574.132876
# 98                            59.651666            65.588141
# 99                            45.628418            43.990318
#
# timestamp           2023-12-31 16:00:00  2023-12-31 17:00:00  \
# station_complex_id
# 1                           1820.936700          1860.737864
# 10                            -0.440530            -0.282214
# 100                         1589.506283          1607.411810
# 101                         1067.845269          1095.022656
# 118                          667.620687           697.952844
# ...                                 ...                  ...
# 95                         13065.054491         12790.290553
# 96                        103016.018004         98734.059152
# 97                           576.991378           600.644661
# 98                            78.728260            68.034038
# 99                            51.496773            49.766238
#
# timestamp           2023-12-31 18:00:00  2023-12-31 19:00:00  \
# station_complex_id
# 1                           1503.311632          1022.321055
# 10                            -0.439614            -0.597290
# 100                         1510.051114          1136.994000
# 101                          972.248272           749.394115
# 118                          675.595294           626.022853
# ...                                 ...                  ...
# 95                         10497.305016          7655.242504
# 96                         83170.135768         57516.778245
# 97                           509.135556           353.403063
# 98                            47.317115            36.662910
# 99                            38.367767            27.690891
#
# timestamp           2023-12-31 20:00:00  2023-12-31 21:00:00  \
# station_complex_id
# 1                            772.504898           592.839719
# 10                            -0.668959            -0.615787
# 100                          842.252609           556.448777
# 101                          578.943325           425.466191
# 118                          563.018533           520.031326
# ...                                 ...                  ...
# 95                          4930.146792          3378.218525
# 96                         39651.962737         30948.198585
# 97                           245.612839           184.271449
# 98                            27.211469            14.803919
# 99                            20.695496            15.327250
#
# timestamp           2023-12-31 22:00:00  2023-12-31 23:00:00
# station_complex_id
# 1                            526.970325           283.512363
# 10                            -0.567656            -0.723216
# 100                          486.363736           375.855151
# 101                          362.705663           283.500614
# 118                          468.548587           330.154780
# ...                                 ...                  ...
# 95                          2710.542999          1735.530425
# 96                         27733.714702         17191.471375
# 97                           174.559387           122.056086
# 98                            11.173865             8.615516
# 99                            11.542998             8.807679
#
# [361 rows x 8016 columns]

# %%
expanded_23_pred.to_pickle(r'D:\capstone_F24\data\Cleaned_data\expanded_23_pred.pkl')

# %%
# Reset index to include station_complex_id as a column
preds_long = expanded_23_pred.reset_index().melt(
    id_vars=["station_complex_id"],  # Columns to keep as identifiers
    var_name="timestamp",           # Name for the 'wide' columns (timestamps)
    value_name="ridership"          # Name for the values in those columns
)

# Convert the timestamp column to a proper datetime type if necessary
preds_long["timestamp"] = pd.to_datetime(preds_long["timestamp"])

preds_long
# Out:
#         station_complex_id           timestamp     ridership
# 0                        1 2023-02-01 00:00:00     44.997743
# 1                       10 2023-02-01 00:00:00      0.637787
# 2                      100 2023-02-01 00:00:00     19.375850
# 3                      101 2023-02-01 00:00:00     65.802439
# 4                      118 2023-02-01 00:00:00     69.094706
# ...                    ...                 ...           ...
# 2893771                 95 2023-12-31 23:00:00   1735.530425
# 2893772                 96 2023-12-31 23:00:00  17191.471375
# 2893773                 97 2023-12-31 23:00:00    122.056086
# 2893774                 98 2023-12-31 23:00:00      8.615516
# 2893775                 99 2023-12-31 23:00:00      8.807679
#
# [2893776 rows x 3 columns]

# %%
# Reset index to include station_complex_id as a column
actual_long = df_filled_23.reset_index().melt(
    id_vars=["station_complex_id"],  # Columns to keep as identifiers
    var_name="timestamp",           # Name for the 'wide' columns (timestamps)
    value_name="ridership"          # Name for the values in those columns
)

# Convert the timestamp column to a proper datetime type if necessary
actual_long["timestamp"] = pd.to_datetime(actual_long["timestamp"])

actual_long
# Out:
#         station_complex_id           timestamp  ridership
# 0                        1 2023-02-01 00:00:00       27.0
# 1                       10 2023-02-01 00:00:00      167.0
# 2                      100 2023-02-01 00:00:00       13.0
# 3                      101 2023-02-01 00:00:00       59.0
# 4                      118 2023-02-01 00:00:00       94.0
# ...                    ...                 ...        ...
# 2893771                 95 2023-12-31 23:00:00       55.0
# 2893772                 96 2023-12-31 23:00:00       51.0
# 2893773                 97 2023-12-31 23:00:00      122.0
# 2893774                 98 2023-12-31 23:00:00       39.0
# 2893775                 99 2023-12-31 23:00:00       27.0
#
# [2893776 rows x 3 columns]

# %%
# Rename the 'ridership' column in preds_long to 'predicted'
preds_long = preds_long.rename(columns={"ridership": "predicted"})

# Rename the 'ridership' column in actual_long to 'actual'
actual_long = actual_long.rename(columns={"ridership": "actual"})

# Merge preds_long with actual_long on 'station_complex_id' and 'timestamp'
pred_vs_actual = actual_long.merge(
    preds_long[["station_complex_id", "timestamp", "predicted"]],  # Select relevant columns from preds_long
    on=["station_complex_id", "timestamp"],                       # Merge on these columns
    how="inner"                                                   # Use inner join to keep only matching rows
)

pred_vs_actual
# Out:
#         station_complex_id           timestamp  actual     predicted
# 0                        1 2023-02-01 00:00:00    27.0     44.997743
# 1                       10 2023-02-01 00:00:00   167.0      0.637787
# 2                      100 2023-02-01 00:00:00    13.0     19.375850
# 3                      101 2023-02-01 00:00:00    59.0     65.802439
# 4                      118 2023-02-01 00:00:00    94.0     69.094706
# ...                    ...                 ...     ...           ...
# 2893771                 95 2023-12-31 23:00:00    55.0   1735.530425
# 2893772                 96 2023-12-31 23:00:00    51.0  17191.471375
# 2893773                 97 2023-12-31 23:00:00   122.0    122.056086
# 2893774                 98 2023-12-31 23:00:00    39.0      8.615516
# 2893775                 99 2023-12-31 23:00:00    27.0      8.807679
#
# [2893776 rows x 4 columns]

# %%
df_filled_22 = pd.read_pickle(r'D:\capstone_F24\data\Cleaned_data\df_filled_22.pkl')

# %%
df_filled_22
# Out:
# timestamp           2022-02-01 00:00:00  2022-02-01 01:00:00  \
# station_complex_id
# 1                                  17.0                  5.0
# 10                                100.0                 24.0
# 100                                10.0                  3.0
# 101                                26.0                 10.0
# 118                                21.0                 11.0
# ...                                 ...                  ...
# 95                                  6.0                  2.0
# 96                                 11.0                  4.0
# 97                                 13.0                 12.0
# 98                                 18.0                  8.0
# 99                                  9.0                  2.0
#
# timestamp           2022-02-01 02:00:00  2022-02-01 03:00:00  \
# station_complex_id
# 1                                   6.0                 12.0
# 10                                  7.0                  8.0
# 100                                 0.0                  3.0
# 101                                 9.0                  3.0
# 118                                 9.0                  3.0
# ...                                 ...                  ...
# 95                                  5.0                  6.0
# 96                                  4.0                  7.0
# 97                                  8.0                 10.0
# 98                                  3.0                  2.0
# 99                                  1.0                  0.0
#
# timestamp           2022-02-01 04:00:00  2022-02-01 05:00:00  \
# station_complex_id
# 1                                  44.0                143.0
# 10                                  8.0                 14.0
# 100                                 5.0                 17.0
# 101                                20.0                 49.0
# 118                                 1.0                  9.0
# ...                                 ...                  ...
# 95                                 24.0                 85.0
# 96                                 15.0                 58.0
# 97                                 39.0                 91.0
# 98                                 14.0                 46.0
# 99                                  2.0                 30.0
#
# timestamp           2022-02-01 06:00:00  2022-02-01 07:00:00  \
# station_complex_id
# 1                                 405.0                735.0
# 10                                 43.0                 98.0
# 100                                46.0                 68.0
# 101                               124.0                245.0
# 118                                14.0                 61.0
# ...                                 ...                  ...
# 95                                135.0                296.0
# 96                                113.0                214.0
# 97                                229.0                357.0
# 98                                127.0                170.0
# 99                                 60.0                105.0
#
# timestamp           2022-02-01 08:00:00  2022-02-01 09:00:00  ...  \
# station_complex_id                                            ...
# 1                                 950.0                512.0  ...
# 10                                175.0                182.0  ...
# 100                               106.0                 66.0  ...
# 101                               394.0                247.0  ...
# 118                                75.0                 54.0  ...
# ...                                 ...                  ...  ...
# 95                                298.0                196.0  ...
# 96                                244.0                169.0  ...
# 97                                472.0                317.0  ...
# 98                                223.0                178.0  ...
# 99                                155.0                123.0  ...
#
# timestamp           2022-12-31 14:00:00  2022-12-31 15:00:00  \
# station_complex_id
# 1                                 426.0                402.0
# 10                                  3.0                  4.0
# 100                                68.0                 69.0
# 101                               286.0                316.0
# 118                               249.0                279.0
# ...                                 ...                  ...
# 95                                227.0                147.0
# 96                                194.0                153.0
# 97                                276.0                247.0
# 98                                189.0                196.0
# 99                                101.0                 82.0
#
# timestamp           2022-12-31 16:00:00  2022-12-31 17:00:00  \
# station_complex_id
# 1                                 304.0                338.0
# 10                                  4.0                  4.0
# 100                                69.0                 55.0
# 101                               332.0                269.0
# 118                               245.0                245.0
# ...                                 ...                  ...
# 95                                160.0                143.0
# 96                                112.0                128.0
# 97                                231.0                198.0
# 98                                188.0                141.0
# 99                                 77.0                 68.0
#
# timestamp           2022-12-31 18:00:00  2022-12-31 19:00:00  \
# station_complex_id
# 1                                 322.0                350.0
# 10                                  3.0                  4.0
# 100                                58.0                 61.0
# 101                               239.0                246.0
# 118                               287.0                273.0
# ...                                 ...                  ...
# 95                                172.0                183.0
# 96                                137.0                175.0
# 97                                261.0                234.0
# 98                                118.0                156.0
# 99                                 80.0                 64.0
#
# timestamp           2022-12-31 20:00:00  2022-12-31 21:00:00  \
# station_complex_id
# 1                                 309.0                293.0
# 10                                  5.0                  8.0
# 100                                67.0                 52.0
# 101                               239.0                209.0
# 118                               278.0                281.0
# ...                                 ...                  ...
# 95                                170.0                151.0
# 96                                181.0                153.0
# 97                                314.0                243.0
# 98                                121.0                 84.0
# 99                                 73.0                 64.0
#
# timestamp           2022-12-31 22:00:00  2022-12-31 23:00:00
# station_complex_id
# 1                                 168.0                 75.0
# 10                                  5.0                  2.0
# 100                                56.0                 25.0
# 101                               179.0                104.0
# 118                               245.0                115.0
# ...                                 ...                  ...
# 95                                116.0                 62.0
# 96                                128.0                 61.0
# 97                                180.0                 83.0
# 98                                 85.0                 39.0
# 99                                 49.0                 24.0
#
# [361 rows x 8016 columns]

# %%
# Reset index to include station_complex_id as a column
actual_22_long = df_filled_22.reset_index().melt(
    id_vars=["station_complex_id"],  # Columns to keep as identifiers
    var_name="timestamp",           # Name for the 'wide' columns (timestamps)
    value_name="ridership"          # Name for the values in those columns
)

# Convert the timestamp column to a proper datetime type if necessary
actual_22_long["timestamp"] = pd.to_datetime(actual_22_long["timestamp"])

actual_22_long
# Out:
#         station_complex_id           timestamp  ridership
# 0                        1 2022-02-01 00:00:00       17.0
# 1                       10 2022-02-01 00:00:00      100.0
# 2                      100 2022-02-01 00:00:00       10.0
# 3                      101 2022-02-01 00:00:00       26.0
# 4                      118 2022-02-01 00:00:00       21.0
# ...                    ...                 ...        ...
# 2893771                 95 2022-12-31 23:00:00       62.0
# 2893772                 96 2022-12-31 23:00:00       61.0
# 2893773                 97 2022-12-31 23:00:00       83.0
# 2893774                 98 2022-12-31 23:00:00       39.0
# 2893775                 99 2022-12-31 23:00:00       24.0
#
# [2893776 rows x 3 columns]

# %%
# Rename the 'ridership' column in actual_long to 'actual'
pred_vs_actual = pred_vs_actual.rename(columns={"actual": "actual_23", "predicted":"pred_23"})

pred_vs_actual
# Out:
#         station_complex_id           timestamp  actual_23       pred_23
# 0                        1 2023-02-01 00:00:00       27.0     44.997743
# 1                       10 2023-02-01 00:00:00      167.0      0.637787
# 2                      100 2023-02-01 00:00:00       13.0     19.375850
# 3                      101 2023-02-01 00:00:00       59.0     65.802439
# 4                      118 2023-02-01 00:00:00       94.0     69.094706
# ...                    ...                 ...        ...           ...
# 2893771                 95 2023-12-31 23:00:00       55.0   1735.530425
# 2893772                 96 2023-12-31 23:00:00       51.0  17191.471375
# 2893773                 97 2023-12-31 23:00:00      122.0    122.056086
# 2893774                 98 2023-12-31 23:00:00       39.0      8.615516
# 2893775                 99 2023-12-31 23:00:00       27.0      8.807679
#
# [2893776 rows x 4 columns]

# %%
df_station_info = pd.read_csv(r"D:\capstone_F24\data\MTA_Subway_Stations_20241002.csv")

# %%
df_station_info
# Out:
#     GTFS Stop ID  Station ID  Complex ID Division           Line  \
# 0            R01           1           1      BMT        Astoria
# 1            R03           2           2      BMT        Astoria
# 2            R04           3           3      BMT        Astoria
# 3            R05           4           4      BMT        Astoria
# 4            R06           5           5      BMT        Astoria
# ..           ...         ...         ...      ...            ...
# 491          S15         517         517      SIR  Staten Island
# 492          S14         518         518      SIR  Staten Island
# 493          S13         519         519      SIR  Staten Island
# 494          S09         522         522      SIR  Staten Island
# 495          S11         523         523      SIR  Staten Island
#
#                 Stop Name Borough    CBD Daytime Routes   Structure  \
# 0    Astoria-Ditmars Blvd       Q  False            N W    Elevated
# 1            Astoria Blvd       Q  False            N W    Elevated
# 2                   30 Av       Q  False            N W    Elevated
# 3                Broadway       Q  False            N W    Elevated
# 4                   36 Av       Q  False            N W    Elevated
# ..                    ...     ...    ...            ...         ...
# 491          Prince's Bay      SI  False            SIR    Open Cut
# 492       Pleasant Plains      SI  False            SIR  Embankment
# 493       Richmond Valley      SI  False            SIR    Open Cut
# 494           Tottenville      SI  False            SIR    At Grade
# 495           Arthur Kill      SI  False            SIR    At Grade
#
#      GTFS Latitude  GTFS Longitude North Direction Label  \
# 0        40.775036      -73.912034             Last Stop
# 1        40.770258      -73.917843               Astoria
# 2        40.766779      -73.921479               Astoria
# 3        40.761820      -73.925508               Astoria
# 4        40.756804      -73.929575               Astoria
# ..             ...             ...                   ...
# 491      40.525507      -74.200064                 Ferry
# 492      40.522410      -74.217847                 Ferry
# 493      40.519631      -74.229141                 Ferry
# 494      40.512764      -74.251961                 Ferry
# 495      40.516578      -74.242096                 Ferry
#
#     South Direction Label  ADA  ADA Northbound  ADA Southbound ADA Notes  \
# 0               Manhattan    0               0               0       NaN
# 1               Manhattan    1               1               1       NaN
# 2               Manhattan    0               0               0       NaN
# 3               Manhattan    0               0               0       NaN
# 4               Manhattan    0               0               0       NaN
# ..                    ...  ...             ...             ...       ...
# 491           South Shore    0               0               0       NaN
# 492           South Shore    0               0               0       NaN
# 493           Tottenville    0               0               0       NaN
# 494             Last Stop    1               1               1       NaN
# 495           Tottenville    1               1               1       NaN
#
#                      Georeference
# 0    POINT (-73.912034 40.775036)
# 1    POINT (-73.917843 40.770258)
# 2    POINT (-73.921479 40.766779)
# 3     POINT (-73.925508 40.76182)
# 4    POINT (-73.929575 40.756804)
# ..                            ...
# 491  POINT (-74.200064 40.525507)
# 492   POINT (-74.217847 40.52241)
# 493  POINT (-74.229141 40.519631)
# 494  POINT (-74.251961 40.512764)
# 495  POINT (-74.242096 40.516578)
#
# [496 rows x 19 columns]

# %%
df_station_info['Daytime Routes'].unique()
# Out:
# array(['N W', 'N R W', 'N Q R W', 'R W', 'N Q', 'R', 'B Q R', 'D N R',
#        'N R', 'B Q', 'B Q S', 'Q', 'F Q', 'D F N Q', 'D', 'N', 'J Z', 'J',
#        'M J Z', 'M J', 'M', 'L', 'S', 'A', 'A C', 'C', 'B D', 'C B',
#        'A C B D', 'C E', 'A C E', 'B D F M', 'E', 'A C F', 'A C G', 'A S',
#        'F', 'F M', 'F G', 'E F', 'E F M R', 'M R', 'E M R', 'E M',
#        'E B D', 'E J Z', 'G', '1', '1 2 3', '2 3', '2 3 4 5', '3', '3 4',
#        '2 5', '6', '4', '4 5', '4 5 6', '2', '5', '7', 'SIR'],
#       dtype=object)

# %%
# Cast Complex ID to string in df_station_info
df_station_info['Complex ID'] = df_station_info['Complex ID'].astype(str)

# Remove duplicates in df_station_info based on Complex ID
df_station_info_unique = df_station_info.drop_duplicates(subset=['Complex ID'])

# Select relevant columns from df_station_info
station_info_cols = ['Complex ID', 'Stop Name', 'Borough', 'Daytime Routes', 
                     'Structure', 'GTFS Latitude', 'GTFS Longitude']
df_station_info_selected = df_station_info_unique[station_info_cols]

# Perform the merge
merged_df = pred_vs_actual.merge(
    df_station_info_selected, 
    left_on='station_complex_id', 
    right_on='Complex ID', 
    how='left'
)

# Drop duplicate 'Complex ID' column if desired
merged_df = merged_df.drop(columns=['Complex ID'])

merged_df
# Out:
#         station_complex_id           timestamp  actual_23       pred_23  \
# 0                        1 2023-02-01 00:00:00       27.0     44.997743
# 1                       10 2023-02-01 00:00:00      167.0      0.637787
# 2                      100 2023-02-01 00:00:00       13.0     19.375850
# 3                      101 2023-02-01 00:00:00       59.0     65.802439
# 4                      118 2023-02-01 00:00:00       94.0     69.094706
# ...                    ...                 ...        ...           ...
# 2893771                 95 2023-12-31 23:00:00       55.0   1735.530425
# 2893772                 96 2023-12-31 23:00:00       51.0  17191.471375
# 2893773                 97 2023-12-31 23:00:00      122.0    122.056086
# 2893774                 98 2023-12-31 23:00:00       39.0      8.615516
# 2893775                 99 2023-12-31 23:00:00       27.0      8.807679
#
#                     Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0        Astoria-Ditmars Blvd       Q            N W  Elevated      40.775036
# 1                       49 St       M          N R W    Subway      40.759901
# 2                    Hewes St      Bk            M J  Elevated      40.706870
# 3                    Marcy Av      Bk          M J Z  Elevated      40.708359
# 4                        3 Av       M              L    Subway      40.732849
# ...                       ...     ...            ...       ...            ...
# 2893771              Gates Av      Bk            J Z  Elevated      40.689630
# 2893772         Kosciuszko St      Bk              J  Elevated      40.693342
# 2893773             Myrtle Av      Bk          M J Z  Elevated      40.697207
# 2893774           Flushing Av      Bk            M J  Elevated      40.700260
# 2893775            Lorimer St      Bk            M J  Elevated      40.703869
#
#          GTFS Longitude
# 0            -73.912034
# 1            -73.984139
# 2            -73.953431
# 3            -73.957757
# 4            -73.986122
# ...                 ...
# 2893771      -73.922270
# 2893772      -73.928814
# 2893773      -73.935657
# 2893774      -73.941126
# 2893775      -73.947408
#
# [2893776 rows x 10 columns]

# %%
# Rename 'GTFS Latitude' and 'GTFS Longitude' columns to 'lat' and 'long' respectively
merged_df.rename(columns={'GTFS Latitude': 'lat', 'GTFS Longitude': 'long', 'Stop Name': 'stop_name', 'Borough': 'borough','Structure': 'structure'}, inplace=True)

# Create proxy variable 'is_weekend' which determines if the timestamp is a weekend (1 for weekend, 0 for weekday)
merged_df['timestamp'] = pd.to_datetime(merged_df['timestamp'])  # Ensure timestamp is in datetime format
merged_df['is_weekend'] = merged_df['timestamp'].dt.weekday >= 5  # 5 and 6 represent Saturday and Sunday
merged_df['is_weekend'] = merged_df['is_weekend'].astype(int)  # Convert boolean to integer (1 for weekend, 0 for weekday)

# Create proxy variable 'day_of_week' which gets the day of the week as an integer (0=Monday, 6=Sunday)
merged_df['day_of_week'] = merged_df['timestamp'].dt.weekday

# Refactor 'Daytime Routes' column into a new column 'routes' which is a list of elements split by space
merged_df['routes'] = merged_df['Daytime Routes'].str.split()

# Add new column 'num_lines_serviced' which is the length of each list in the 'routes' column
merged_df['num_lines_serviced'] = merged_df['routes'].apply(len)

# Drop the 'Daytime Routes' column
merged_df.drop(columns=['Daytime Routes'], inplace=True)

# %%
merged_df
# Out:
#         station_complex_id           timestamp  actual_23       pred_23  \
# 0                        1 2023-02-01 00:00:00       27.0     44.997743
# 1                       10 2023-02-01 00:00:00      167.0      0.637787
# 2                      100 2023-02-01 00:00:00       13.0     19.375850
# 3                      101 2023-02-01 00:00:00       59.0     65.802439
# 4                      118 2023-02-01 00:00:00       94.0     69.094706
# ...                    ...                 ...        ...           ...
# 2893771                 95 2023-12-31 23:00:00       55.0   1735.530425
# 2893772                 96 2023-12-31 23:00:00       51.0  17191.471375
# 2893773                 97 2023-12-31 23:00:00      122.0    122.056086
# 2893774                 98 2023-12-31 23:00:00       39.0      8.615516
# 2893775                 99 2023-12-31 23:00:00       27.0      8.807679
#
#                     stop_name borough structure        lat       long  \
# 0        Astoria-Ditmars Blvd       Q  Elevated  40.775036 -73.912034
# 1                       49 St       M    Subway  40.759901 -73.984139
# 2                    Hewes St      Bk  Elevated  40.706870 -73.953431
# 3                    Marcy Av      Bk  Elevated  40.708359 -73.957757
# 4                        3 Av       M    Subway  40.732849 -73.986122
# ...                       ...     ...       ...        ...        ...
# 2893771              Gates Av      Bk  Elevated  40.689630 -73.922270
# 2893772         Kosciuszko St      Bk  Elevated  40.693342 -73.928814
# 2893773             Myrtle Av      Bk  Elevated  40.697207 -73.935657
# 2893774           Flushing Av      Bk  Elevated  40.700260 -73.941126
# 2893775            Lorimer St      Bk  Elevated  40.703869 -73.947408
#
#          is_weekend  day_of_week     routes  num_lines_serviced
# 0                 0            2     [N, W]                   2
# 1                 0            2  [N, R, W]                   3
# 2                 0            2     [M, J]                   2
# 3                 0            2  [M, J, Z]                   3
# 4                 0            2        [L]                   1
# ...             ...          ...        ...                 ...
# 2893771           1            6     [J, Z]                   2
# 2893772           1            6        [J]                   1
# 2893773           1            6  [M, J, Z]                   3
# 2893774           1            6     [M, J]                   2
# 2893775           1            6     [M, J]                   2
#
# [2893776 rows x 13 columns]

# %%
# Assuming your DataFrame is named df
merged_df['diff_23'] = merged_df['pred_23'] - merged_df['actual_23']

# %%
merged_df
# Out:
#         station_complex_id           timestamp  actual_23       pred_23  \
# 0                        1 2023-02-01 00:00:00       27.0     44.997743
# 1                       10 2023-02-01 00:00:00      167.0      0.637787
# 2                      100 2023-02-01 00:00:00       13.0     19.375850
# 3                      101 2023-02-01 00:00:00       59.0     65.802439
# 4                      118 2023-02-01 00:00:00       94.0     69.094706
# ...                    ...                 ...        ...           ...
# 2893771                 95 2023-12-31 23:00:00       55.0   1735.530425
# 2893772                 96 2023-12-31 23:00:00       51.0  17191.471375
# 2893773                 97 2023-12-31 23:00:00      122.0    122.056086
# 2893774                 98 2023-12-31 23:00:00       39.0      8.615516
# 2893775                 99 2023-12-31 23:00:00       27.0      8.807679
#
#                     stop_name borough structure        lat       long  \
# 0        Astoria-Ditmars Blvd       Q  Elevated  40.775036 -73.912034
# 1                       49 St       M    Subway  40.759901 -73.984139
# 2                    Hewes St      Bk  Elevated  40.706870 -73.953431
# 3                    Marcy Av      Bk  Elevated  40.708359 -73.957757
# 4                        3 Av       M    Subway  40.732849 -73.986122
# ...                       ...     ...       ...        ...        ...
# 2893771              Gates Av      Bk  Elevated  40.689630 -73.922270
# 2893772         Kosciuszko St      Bk  Elevated  40.693342 -73.928814
# 2893773             Myrtle Av      Bk  Elevated  40.697207 -73.935657
# 2893774           Flushing Av      Bk  Elevated  40.700260 -73.941126
# 2893775            Lorimer St      Bk  Elevated  40.703869 -73.947408
#
#          is_weekend  day_of_week     routes  num_lines_serviced       diff_23
# 0                 0            2     [N, W]                   2     17.997743
# 1                 0            2  [N, R, W]                   3   -166.362213
# 2                 0            2     [M, J]                   2      6.375850
# 3                 0            2  [M, J, Z]                   3      6.802439
# 4                 0            2        [L]                   1    -24.905294
# ...             ...          ...        ...                 ...           ...
# 2893771           1            6     [J, Z]                   2   1680.530425
# 2893772           1            6        [J]                   1  17140.471375
# 2893773           1            6  [M, J, Z]                   3      0.056086
# 2893774           1            6     [M, J]                   2    -30.384484
# 2893775           1            6     [M, J]                   2    -18.192321
#
# [2893776 rows x 14 columns]

# %%
import sys
# !{sys.executable} -m pip install jupyter-dash dash plotly
# Out:
# Requirement already satisfied: jupyter-dash in c:\programdata\miniconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: dash in c:\programdata\miniconda3\lib\site-packages (2.18.2)
# Requirement already satisfied: plotly in c:\programdata\miniconda3\lib\site-packages (5.24.1)
# Requirement already satisfied: requests in c:\programdata\miniconda3\lib\site-packages (from jupyter-dash) (2.32.3)
# Requirement already satisfied: flask in c:\programdata\miniconda3\lib\site-packages (from jupyter-dash) (3.0.3)
# Requirement already satisfied: retrying in c:\programdata\miniconda3\lib\site-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in c:\programdata\miniconda3\lib\site-packages (from jupyter-dash) (8.29.0)
# Requirement already satisfied: ipykernel in c:\programdata\miniconda3\lib\site-packages (from jupyter-dash) (6.29.5)
# Requirement already satisfied: ansi2html in c:\programdata\miniconda3\lib\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in c:\programdata\miniconda3\lib\site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\programdata\miniconda3\lib\site-packages (from dash) (3.0.6)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\programdata\miniconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\programdata\miniconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\programdata\miniconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\miniconda3\lib\site-packages (from dash) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\programdata\miniconda3\lib\site-packages (from dash) (4.12.2)
# Requirement already satisfied: setuptools in c:\programdata\miniconda3\lib\site-packages (from dash) (72.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\miniconda3\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\programdata\miniconda3\lib\site-packages (from plotly) (24.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\miniconda3\lib\site-packages (from flask->jupyter-dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\programdata\miniconda3\lib\site-packages (from flask->jupyter-dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\programdata\miniconda3\lib\site-packages (from flask->jupyter-dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\programdata\miniconda3\lib\site-packages (from flask->jupyter-dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\miniconda3\lib\site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in c:\programdata\miniconda3\lib\site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.8.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.7)
# Requirement already satisfied: psutil in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\programdata\miniconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in c:\programdata\miniconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\miniconda3\lib\site-packages (from ipython->jupyter-dash) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\miniconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\miniconda3\lib\site-packages (from ipython->jupyter-dash) (2.18.0)
# Requirement already satisfied: stack-data in c:\programdata\miniconda3\lib\site-packages (from ipython->jupyter-dash) (0.6.3)
# Requirement already satisfied: colorama in c:\programdata\miniconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\miniconda3\lib\site-packages (from requests->jupyter-dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\miniconda3\lib\site-packages (from requests->jupyter-dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\miniconda3\lib\site-packages (from requests->jupyter-dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\lib\site-packages (from requests->jupyter-dash) (2024.7.4)
# Requirement already satisfied: six>=1.7.0 in c:\programdata\miniconda3\lib\site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\programdata\miniconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\miniconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\miniconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\miniconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (308)
# Requirement already satisfied: wcwidth in c:\programdata\miniconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\programdata\miniconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\programdata\miniconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.4.1)
# Requirement already satisfied: pure-eval in c:\programdata\miniconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.3)

# %%
from jupyter_dash import JupyterDash
from dash import dcc, html, Input, Output
import plotly.graph_objs as go

# %%
# Create the Dash app (JupyterDash)
app = JupyterDash(__name__)

app.layout = html.Div([
    html.H1("NYC Subway Ridership Predictions"),
    
    # Dropdown to select station_complex_id
    dcc.Dropdown(
        id='station-dropdown',
        options=[{'label': station, 'value': station} for station in merged_df['station_complex_id'].unique()],
        value=merged_df['station_complex_id'].iloc[0],  # Default value
        clearable=False
    ),
    
    # First plot: Predicted vs Actual
    dcc.Graph(id='pred-vs-actual-plot'),
    
    # Second plot: Difference
    dcc.Graph(id='difference-plot')
])

# Callback to update plots based on dropdown selection
@app.callback(
    [Output('pred-vs-actual-plot', 'figure'),
     Output('difference-plot', 'figure')],
    [Input('station-dropdown', 'value')]
)
def update_graphs(selected_station):
    filtered_df = merged_df[merged_df['station_complex_id'] == selected_station]
    
    # First Plot: Predicted vs Actual
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(
        x=filtered_df['timestamp'],
        y=filtered_df['pred_23'],
        mode='lines+markers',
        name='Predicted Ridership'
    ))
    fig1.add_trace(go.Scatter(
        x=filtered_df['timestamp'],
        y=filtered_df['actual_23'],
        mode='lines+markers',
        name='Actual Ridership'
    ))
    fig1.update_layout(title='Predicted vs Actual Ridership',
                       xaxis_title='Time',
                       yaxis_title='Ridership')

    # Second Plot: Difference with conditional coloring
    fig2 = go.Figure()
    fig2.add_trace(go.Bar(
        x=filtered_df['timestamp'],
        y=filtered_df['diff_23'],
        marker_color=[
            'green' if val > 0 else 'red' for val in filtered_df['diff_23']
        ],
        name='Difference'
    ))
    fig2.update_layout(title='Prediction Difference (Over/Underestimation)',
                       xaxis_title='Time',
                       yaxis_title='Difference',
                       showlegend=False)

    return fig1, fig2

# Run the app inside the notebook
app.run_server(mode="inline", host="136.50.150.50", port=8080)
# Out:
# The requested address is not valid in its context
